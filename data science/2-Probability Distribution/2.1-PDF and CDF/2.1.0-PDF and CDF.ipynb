# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt #showing

# %% [markdown]
# # Normal Distribution
# Normal Distribution is used for <b>Continuous</b> types of data.
# <img src="NDExample.bmp"> <img src="NDExample2.bmp">
# For more details about Normal Distribution, go to the following website:<b> https://www.mathsisfun.com/data/standard-normal-distribution.html </b>

# %% [markdown]
# ## PDF
# PDF is <b>Probability Density Function</b> and the probability <b>P</b> of a value <b>V</b> to occur between limits A and B(briefly written as P(a<V<b) ) is found by the area under the <b>PDF curve between A and B</b>
# <br>Example: The <b>area</b> between <b>a and b</b> can be found by PDF function in the following example <img src="NDPDFExample.bmp">
# The formula is <img src="NDPDFFormula.bmp">

# %% [markdown]
# ## CDF
# CDF is Cumulative Distribution Function and is a probability that a random variable takes a value <b>less than or equal to x</b>. <img src="NDCDFExample.bmp">
# Let's try to see both PDF and CDF for Normal Distribution in one graph: <img src="NDPDFCDFExample.bmp">

# %% [markdown]
# # Exponential Distribution
# This is another type of probability distribution and it is also used for Continuous types of data.
# ### PDF and CDF of an Exponential Distribution
# <img src="EDExample.bmp">

# %% [markdown]
# Formulas of PDF and CDF(Exponential Distribution): <img src="EDFormula.bmp">

# %% [markdown]
# # Binomial Distribution
# This distribution is used to represent <b>Discrete</b> type of data
# <img src="BDExample.bmp">
# For more information about Binomial Distribution, https://www.mathsisfun.com/data/binomial-distribution.html

# %% [markdown]
# For Discrete type, we use <b>PMF(Probability Mass Function)</b> instead of PDF, but we still have <b>CDF</b> for discrete datatypes
# <br>PMF of a Binomial Distribution looks like the graph below: <img src="BDPMFExample.bmp">
# <img src="BDPMFCDFExample.bmp">

# %% [markdown]
# Graph above represents <b>PMF and CDF</b> of a Binomial Distribution
# <br>And PMF formula looks like this: <img src="BDPMFFormula.bmp">
# Formula for CDF: <img src="BDCDFFormula.bmp">
