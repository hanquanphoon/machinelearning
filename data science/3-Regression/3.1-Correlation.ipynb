# %% [markdown]
# # <font color = "orange">Correlation</font>

# %% [markdown]
# ## 1.0 General Explanation about <font color ="orange">Correlation</font>
#
# -  Correlation shows the strength of relationship that occurs between two variables <font color = blue>(independent and dependent variable)</font> linearly.
# -  Correlation is not causation - it does not implies the influence/impact of the variables to another variables.
# <img src="1st.png" width = 500 height = 300>

# %% [markdown]
# ### 1.1 Further explanation in <font color = "orange">Correlation</font>

# %%
# %%HTML
#
# <iframe width="700" height="350" src="https://www.youtube.com/embed/Ypgo4qUBt5o" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="700" height="350" src="https://www.youtube.com/embed/Ypgo4qUBt5o" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ### 1.2 Type of relation in <font color = "orange">Correlation</font>
#
# <img src="5th.png" width = 500 height = 300>
#
#
# **<font color="blue">1.  Positive linear correlation</font>**
#     -  when x is increasing, y is also increasing.
#     -  shows a positive gradient.
#     -  shows the direction of line in a positive way.
#
# **<font color="blue">2.  Negative linear correlation</font>**
#     -  when x is increasing, y is decreasing.
#     -  shows a negative gradient.
#     -  shows the direction of line in a negative way.
#
# **<font color="blue">3.  Zero Correlation</font>**
#     -  when x increases or decreases, there will be no change to y.
#     -  x is not affecting y or x has no relationship with y.
#     -  shows a zero gradient, m = 0.

# %% [markdown]
# ### 1.3 Formula for <font color = "orange">Correlation</font>
#
# <img src="12th.png" width = 500 height = 300 align = "center">
# <img src="10th.png" width = 700 height = 300 align = "center">
# -   r = correlation coefficient
# -   N = number of sample
# -  ∑x = summation of x
# -  ∑y = summation of y
# - ∑x2 = summation of x2
# - ∑y2 = summation of y2
# - (∑x)2 = summation of x-squared
# - (∑y)2 = summation of y-squared

# %% [markdown]
# ## 2.0 Example 1 for <font color="orange">Correlation</font>
#
# The local ice cream shop keeps track of how much ice cream they sell versus the temperature on that day, here are their figures for the last 12 days:

# %%
#creating table using pandas library by inserting data
import pandas as pd

temperature = [14.2, 16.4, 11.9, 15.2, 18.5, 22.1, 19.4, 25.1, 23.4, 18.1, 22.6, 17.2]
sales = [215, 325, 185, 332, 406, 522, 412, 614, 544, 421, 445, 408]

question_table = pd.DataFrame(temperature, columns = ['Temperature']);question_table['Sales'] = sales
question_table
question_table.style.set_properties(**{'text-align': 'center'})
# Out:
#         <style  type="text/css" >
#
#
#             #T_e7b54df0_8126_11e9_a0fa_782bcb97f042row0_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7b54df0_8126_11e9_a0fa_782bcb97f042row0_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7b54df0_8126_11e9_a0fa_782bcb97f042row1_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7b54df0_8126_11e9_a0fa_782bcb97f042row1_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7b54df0_8126_11e9_a0fa_782bcb97f042row2_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7b54df0_8126_11e9_a0fa_782bcb97f042row2_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7b54df0_8126_11e9_a0fa_782bcb97f042row3_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7b54df0_8126_11e9_a0fa_782bcb97f042row3_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7b54df0_8126_11e9_a0fa_782bcb97f042row4_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7b54df0_8126_11e9_a0fa_782bcb97f042row4_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7b54df0_8126_11e9_a0fa_782bcb97f042row5_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7b54df0_8126_11e9_a0fa_782bcb97f042row5_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7b54df0_8126_11e9_a0fa_782bcb97f042row6_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7b54df0_8126_11e9_a0fa_782bcb97f042row6_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7b54df0_8126_11e9_a0fa_782bcb97f042row7_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7b54df0_8126_11e9_a0fa_782bcb97f042row7_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7b54df0_8126_11e9_a0fa_782bcb97f042row8_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7b54df0_8126_11e9_a0fa_782bcb97f042row8_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7b54df0_8126_11e9_a0fa_782bcb97f042row9_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7b54df0_8126_11e9_a0fa_782bcb97f042row9_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7b54df0_8126_11e9_a0fa_782bcb97f042row10_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7b54df0_8126_11e9_a0fa_782bcb97f042row10_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7b54df0_8126_11e9_a0fa_782bcb97f042row11_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7b54df0_8126_11e9_a0fa_782bcb97f042row11_col1 {
#
#                 text-align:  center;
#
#             }
#
#         </style>
#
#         <table id="T_e7b54df0_8126_11e9_a0fa_782bcb97f042" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">Temperature
#
#                 <th class="col_heading level0 col1">Sales
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_e7b54df0_8126_11e9_a0fa_782bcb97f042" class="row_heading level1 row0">
#                     0
#
#                 <td id="T_e7b54df0_8126_11e9_a0fa_782bcb97f042row0_col0" class="data row0 col0">
#                     14.2
#
#                 <td id="T_e7b54df0_8126_11e9_a0fa_782bcb97f042row0_col1" class="data row0 col1">
#                     215
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_e7b54df0_8126_11e9_a0fa_782bcb97f042" class="row_heading level1 row1">
#                     1
#
#                 <td id="T_e7b54df0_8126_11e9_a0fa_782bcb97f042row1_col0" class="data row1 col0">
#                     16.4
#
#                 <td id="T_e7b54df0_8126_11e9_a0fa_782bcb97f042row1_col1" class="data row1 col1">
#                     325
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_e7b54df0_8126_11e9_a0fa_782bcb97f042" class="row_heading level1 row2">
#                     2
#
#                 <td id="T_e7b54df0_8126_11e9_a0fa_782bcb97f042row2_col0" class="data row2 col0">
#                     11.9
#
#                 <td id="T_e7b54df0_8126_11e9_a0fa_782bcb97f042row2_col1" class="data row2 col1">
#                     185
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_e7b54df0_8126_11e9_a0fa_782bcb97f042" class="row_heading level1 row3">
#                     3
#
#                 <td id="T_e7b54df0_8126_11e9_a0fa_782bcb97f042row3_col0" class="data row3 col0">
#                     15.2
#
#                 <td id="T_e7b54df0_8126_11e9_a0fa_782bcb97f042row3_col1" class="data row3 col1">
#                     332
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_e7b54df0_8126_11e9_a0fa_782bcb97f042" class="row_heading level1 row4">
#                     4
#
#                 <td id="T_e7b54df0_8126_11e9_a0fa_782bcb97f042row4_col0" class="data row4 col0">
#                     18.5
#
#                 <td id="T_e7b54df0_8126_11e9_a0fa_782bcb97f042row4_col1" class="data row4 col1">
#                     406
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_e7b54df0_8126_11e9_a0fa_782bcb97f042" class="row_heading level1 row5">
#                     5
#
#                 <td id="T_e7b54df0_8126_11e9_a0fa_782bcb97f042row5_col0" class="data row5 col0">
#                     22.1
#
#                 <td id="T_e7b54df0_8126_11e9_a0fa_782bcb97f042row5_col1" class="data row5 col1">
#                     522
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_e7b54df0_8126_11e9_a0fa_782bcb97f042" class="row_heading level1 row6">
#                     6
#
#                 <td id="T_e7b54df0_8126_11e9_a0fa_782bcb97f042row6_col0" class="data row6 col0">
#                     19.4
#
#                 <td id="T_e7b54df0_8126_11e9_a0fa_782bcb97f042row6_col1" class="data row6 col1">
#                     412
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_e7b54df0_8126_11e9_a0fa_782bcb97f042" class="row_heading level1 row7">
#                     7
#
#                 <td id="T_e7b54df0_8126_11e9_a0fa_782bcb97f042row7_col0" class="data row7 col0">
#                     25.1
#
#                 <td id="T_e7b54df0_8126_11e9_a0fa_782bcb97f042row7_col1" class="data row7 col1">
#                     614
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_e7b54df0_8126_11e9_a0fa_782bcb97f042" clas

# %% [markdown]
# <img src="8th.png" width = 500 height = 300 align = "center">
# <img src="9th.png" width = 500 height = 300 align = "center">

# %% [markdown]
# ### 2.1 Calculating the <font color = "orange">Correlation</font> coefficient step by step:

# %%
x = [14.2, 16.4, 11.9, 15.2, 18.5, 22.1, 19.4, 25.1, 23.4, 18.1, 22.6, 17.2]
y = [215, 325, 185, 332, 406, 522, 412, 614, 544, 421, 445, 408]

#1st Step: Find the mean of x and mean of y
meanX = sum(x) / len(x)
meanY = sum(y) / len(y)

print "1. Mean of Temperature (celcius) is ", meanX
print "2. Mean of Ice Cream Sales ($) is ", meanY

#2nd Step: Subtract the mean of x from every x value (assign as a), and the mean of y from y value (assign as as b)
a = []
for i in x:
    differentFromMeanX = i - meanX
    a.append(differentFromMeanX)
    #print "List of a is ", a

b = []
for i in y:
    differentFromMeanY = i - meanY
    b.append(differentFromMeanY)
    #print "List of b is ", b

#3rd Step: Calculate (a x b), summation of a-squared and summation of b-squared
ab = []
for i in range(len(a)):
    ab.append(a[i]*b[i])
    #print "List of (a x b) is ", ab

aSquared = []
for i in x:
    differentFromMeanX = i - meanX
    aSquared.append((differentFromMeanX)**2)
    #print "List of a-squared is ", aSquared

bSquared = []
for i in y:
    differentFromMeanY = i - meanY
    bSquared.append((differentFromMeanY)**2)
    #print "List of b-squared is ", bSquared

#4th Step: Sum up ab, sum up a-squared and sum up b-squared
print "3. Summation of (a x b) is ", sum(ab)
print "4. Summation of a-squared is ", sum(aSquared)
print "5. Summation of b-squared is ", sum(bSquared)

#5th Step: Divide the sum of ab by the square root of [(sum of a-squared) x (sum of b-squared)]
AB = ((sum(aSquared)) * (sum(bSquared)))
sqrtAB = AB ** (0.5)

r = sum(ab) / sqrtAB
print "6. The correlation coefficient, r is ", r
# Out:
# 1. Mean of Temperature (celcius) is  18.675
# 2. Mean of Ice Cream Sales ($) is  402
# 3. Summation of (a x b) is  5325.025
# 4. Summation of a-squared is  176.9825
# 5. Summation of b-squared is  174757
# 6. The correlation coefficient, r is  0.957500915615

# %% [markdown]
# ### 2.2 Straight away <font color = "orange">USE NUMPY</font>!

# %%
import numpy as np 
np.corrcoef(x, y)
# Out:
# array([[ 1.        ,  0.95750662],
#        [ 0.95750662,  1.        ]])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x = [14.2, 16.4, 11.9, 15.2, 18.5, 22.1, 19.4, 25.1, 23.4, 18.1, 22.6, 17.2]
y = [215, 325, 185, 332, 406, 522, 412, 614, 544, 421, 445, 408]

plt.scatter(x, y, c = "blue", s = 100, marker = "o")
plt.xlabel("Temperature (Celcius)", fontsize = 12); plt.ylabel("Ice Cream Sales ($)", fontsize = 12)
plt.xticks(size = 10); plt.yticks(size = 10)
plt.title("Temperature (Celcius) versus Ice Cream Sales ($)", fontsize = 15)
plt.legend(fontsize = 12, loc = (1, 1))
plt.show();
# Out:
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# -  We can easily see that <font color="red">**the warmer the weather, the higher sales go together**</font>.
# -  Or mathematically we can say that, <font color="red">**as temperature increase, sales are also increase**</font>.
# -  The relationship is good but not perfect. In fact the correlation is 0.9575.

# %% [markdown]
# ## Example 2 for <font color = "orange">Correlation</font>
#
# Study was conducted to investigate the relationship between <font color = "red">score in Data Science</font> and <font color = "red">weight in kilogram</font> among students.

# %%
import pandas as pd

score = [3, 5, 8, 10, 13, 15, 18, 20, 28, 32, 35, 39, 40, 40, 42, 43, 45, 46, 47, 48]
weight = [30, 32, 34, 35, 38, 39, 41, 43, 44, 46, 47, 50, 51, 53, 54, 58, 60, 65, 66, 70]

table = pd.DataFrame(score, columns = ['Score ( /50)']); table['Weight (kg)'] = weight
table
table.style.set_properties(**{'text-align':'center'})
# Out:
#         <style  type="text/css" >
#
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row0_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row0_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row1_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row1_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row2_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row2_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row3_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row3_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row4_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row4_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row5_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row5_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row6_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row6_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row7_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row7_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row8_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row8_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row9_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row9_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row10_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row10_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row11_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row11_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row12_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row12_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row13_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row13_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row14_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row14_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row15_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row15_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row16_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row16_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row17_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row17_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row18_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row18_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row19_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_4a8ecf70_812f_11e9_842f_782bcb97f042row19_col1 {
#
#                 text-align:  center;
#
#             }
#
#         </style>
#
#         <table id="T_4a8ecf70_812f_11e9_842f_782bcb97f042" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">Score ( /50)
#
#                 <th class="col_heading level0 col1">Weight (kg)
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_4a8ecf70_812f_11e9_842f_782bcb97f042" class="row_heading level1 row0">
#                     0
#
#                 <td id="T_4a8ecf70_812f_11e9_842f_782bcb97f042row0_col0" class="data row0 col0">
#                     3
#
#                 <td id="T_4a8ecf70_812f_11e9_842f_782bcb97f042row0_col1" class="data row0 col1">
#                     30
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_4a8ecf70_812f_11e9_842f_782bcb97f042" class="row_heading level1 row1">
#                     1
#
#                 <td id="T_4a8ecf70_812f_11e9_842f_782bcb97f042row1_col0" class="data row1 col0">
#                     5
#
#                 <td id="T_4a8ecf70_812f_11e9_842f_782bcb97f042row1_col1" class="data row1 col1">
#                     32
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_4a8ecf70_812f_11e9_842f_782bcb97f042" class="row_heading level1 row2">
#                     2
#
#                 <td id="T_4a8ecf70_812f_11e9_842f_782bcb97f042row2_col0" class="data row2 col0">
#                     8
#
#                 <td id="T_4a8ecf70_812f_11e9_842f_782bcb97f042row2_col1" class="data row2 col1">
#                     34
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_4a8ecf70_812f_11e9_842f_782bcb97f042"

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x = [3, 5, 8, 10, 13, 15, 18, 20, 28, 32, 35, 39, 40, 40, 42, 43, 45, 46, 47, 48]
y = [30, 32, 34, 35, 38, 39, 41, 43, 44, 46, 47, 50, 51, 53, 54, 58, 60, 65, 66, 70]

plt.scatter(x, y, c ="red", s = 100, marker = "o")
plt.xlabel('Score in Data Science', fontsize = 12); plt.ylabel('Weight in kilograms', fontsize = 12)
plt.xticks(size = 10); plt.yticks(size = 10)
plt.title('Relationship between Score in Data Science and Weight in kg', fontsize = 12)
plt.legend(fontsize = 12, loc = (1, 1))
plt.show();

# %%
import numpy as np

np.corrcoef(x, y)
# Out:
# array([[ 1.        ,  0.95040736],
#        [ 0.95040736,  1.        ]])

# %% [markdown]
# ## 3.0 Question for <font color = "orange">Correlation</font>

# %% [markdown]
# ### <font color = "maroon">Question 1</font>
#
# Taller people tend to weigh more and shorter people tend to weigh less. By referring to table below, create a list of Height (as x) and a list of Weight (as y). Predict type of relation between these two lists of data.

# %%
import pandas as pd

height = [173.0, 173.0, 162.0, 163.0, 152.0, 172.0, 170.0, 171.0, 163.9, 151.0, 149.9, 149.9, 164.0, 180.0, 167.0]
weight = [50, 73, 53, 85, 74, 62, 75, 68, 65, 78, 50, 62, 57, 85, 51]

table = pd.DataFrame(height, columns = ['Height (cm)']); table['Weight (kg)'] = weight
table
table.style.set_properties(**{'text-align' : 'center'})
# Out:
#         <style  type="text/css" >
#
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row0_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row0_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row1_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row1_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row2_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row2_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row3_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row3_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row4_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row4_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row5_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row5_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row6_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row6_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row7_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row7_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row8_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row8_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row9_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row9_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row10_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row10_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row11_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row11_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row12_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row12_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row13_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row13_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row14_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_e7967c11_81ba_11e9_873f_782bcb97f042row14_col1 {
#
#                 text-align:  center;
#
#             }
#
#         </style>
#
#         <table id="T_e7967c11_81ba_11e9_873f_782bcb97f042" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">Height (cm)
#
#                 <th class="col_heading level0 col1">Weight (kg)
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_e7967c11_81ba_11e9_873f_782bcb97f042" class="row_heading level1 row0">
#                     0
#
#                 <td id="T_e7967c11_81ba_11e9_873f_782bcb97f042row0_col0" class="data row0 col0">
#                     173
#
#                 <td id="T_e7967c11_81ba_11e9_873f_782bcb97f042row0_col1" class="data row0 col1">
#                     50
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_e7967c11_81ba_11e9_873f_782bcb97f042" class="row_heading level1 row1">
#                     1
#
#                 <td id="T_e7967c11_81ba_11e9_873f_782bcb97f042row1_col0" class="data row1 col0">
#                     173
#
#                 <td id="T_e7967c11_81ba_11e9_873f_782bcb97f042row1_col1" class="data row1 col1">
#                     73
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_e7967c11_81ba_11e9_873f_782bcb97f042" class="row_heading level1 row2">
#                     2
#
#                 <td id="T_e7967c11_81ba_11e9_873f_782bcb97f042row2_col0" class="data row2 col0">
#                     162
#
#                 <td id="T_e7967c11_81ba_11e9_873f_782bcb97f042row2_col1" class="data row2 col1">
#                     53
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_e7967c11_81ba_11e9_873f_782bcb97f042" class="row_heading level1 row3">
#                     3
#
#                 <td id="T_e7967c11_81ba_11e9_873f_782bcb97f042row3_col0" class="data row3 col0">
#                     163
#
#                 <td id="T_e7967c11_81ba_11e9_873f_782bcb97f042row3_col1" class="data row3 col1">
#                     85
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_e7967c11_81ba_11e9_873f_782bcb97f042" class="row_heading level1 row4">
#                     4
#
#                 <td id="T_e7967c11_81ba_11e9_873f_782bcb97f042row4_col0" class="data row4 col0">
#                     152
#
#                 <td id="T_e7967c11_81ba_11e9_873f_782bcb97f042row4_col1" class="data row4 col1">
#                     74
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_e7967c11_81ba_11e9_873f_782bcb97f042" class="row_heading level1 row5">
#                     5
#
#                 <td id="T_e7967c11_81ba_11e9_873f_782bcb97f042row5_col0" class="data row5 col0">
#                     172
#
#                 <td id="T_e7967c11_81ba_11e9_873f_782bcb97f042row5_col1" class="data row5 col1">
#                     62
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_e7967c11_81ba_11e9_873f_782bcb97f042" class="row_heading level1 row6">
#                     6

# %% [markdown]
# ### <font color = "maroon">Question 2</font>
#
# By referring to table in Question 1, import **matplotlib.pyplot** to draw a scatter plot graph of Height (cm) versus Weight (kg). Label of both axes, ticks, title and legend should be in your graph.
#
# From your plotted graph, write a conclusion about these two variables and the type of relation exists between them.

# %%
height = [173.0, 173.0, 162.0, 163.0, 152.0, 172.0, 170.0, 171.0, 163.9, 151.0, 149.9, 149.9, 164.0, 180.0, 167.0]
weight = [50, 73, 53, 85, 74, 62, 75, 68, 65, 78, 50, 62, 57, 85, 51]

import matplotlib.pyplot as plt

plt.scatter( height, weight, c = "maroon", s = 100, marker = "o")
plt.xlabel("Height (cm)", fontsize = 12); plt.ylabel("Weight (kg)", fontsize = 12)
plt.xticks(size = 10); plt.yticks(size = 10)
plt.title("Height (cm) versus Weight (kg)", fontsize = 15)
plt.show();

# %% [markdown]
# ### <font color = "maroon">Question 3</font>
#
# By referring to table in Question 1, calculate the **correlation coefficient, r** step by step.

# %%
height = [173.0, 173.0, 162.0, 163.0, 152.0, 172.0, 170.0, 171.0, 163.9, 151.0, 149.9, 149.9, 164.0, 180.0, 167.0]
weight = [50, 73, 53, 85, 74, 62, 75, 68, 65, 78, 50, 62, 57, 85, 51]

#Step 1: Find the mean of height and mean of weight
meanHeight = sum(height) / len(height)
meanWeight = sum(weight) / len(weight)

print "1. Mean of Height (cm) is ", meanHeight
print "2. Mean of Weight (kg) is ", meanWeight

#Step 2: Subtract the mean of height from every height value (assign as a) and mean of weight from every weight value (assign as b)
a = []
for i in height:
    a.append(i - meanHeight)

b = []
for j in weight:
    b.append(j - meanWeight)

#Step 3: Calculate (a x b), summation of a-squared and summation of b-squared
ab = []
for k in range(len(a)):
    ab.append(a[k] * b[k])

aSquared = []
for l in height:
    aSquared.append((l - meanHeight) ** 2)

bSquared = []
for m in weight:
    bSquared.append((m - meanWeight) ** 2)

#Step 4: Sum up ab, sum up aSquared and bSquared

print "3. Summation of (a x b) is ", sum(ab)
print "4. Summation of a-squared is ", sum(aSquared)
print "5. Summation od b-squared is ", sum(bSquared)

#Step 5: Find the correlation coefficient, r
AB = ((sum(aSquared)) * (sum(bSquared)))
sqrtAB = AB ** (0.5)

r = sum(ab) / sqrtAB
print "6. The correlation coefficient, r is ", r
# Out:
# 1. Mean of Height (cm) is  164.113333333
# 2. Mean of Weight (kg) is  65
# 3. Summation of (a x b) is  251.326666667
# 4. Summation of a-squared is  1291.43733333
# 5. Summation od b-squared is  2095
# 6. The correlation coefficient, r is  0.152795262567

# %% [markdown]
# ### <font color = "maroon">Question 4</font>
#
# By referring to table in Question 1, import **numpy** and use it to calculate **the correlation coefficient, r** and compare with your previous **r**.

# %%
import numpy as np

np.corrcoef(height, weight)
# Out:
# array([[ 1.        ,  0.15320778],
#        [ 0.15320778,  1.        ]])

# %% [markdown]
# ### <font color = "orange">Question 5</font>
#
# Table below shows a list of 50 students with the days they present to class in one semester and the GPA they got for that semester. Studies show, a student who has many absence has a decrease in GPA. By referring to table below, create list for Days Present (as x) and GPA (as y). Predict type of relation between these two lists of data.

# %%
import pandas as pd

days = [180, 150, 170, 180, 177, 180, 140, 169, 168, 152, 150, 170, 109, 180, 108, 175, 144, 120, 133, 160, 160, 159, 165, 180, 149, 180, 160, 155, 156, 145, 122, 131, 156, 166, 170, 155, 158, 170, 160, 165, 159, 119, 168, 175, 161, 160, 160, 150, 140, 148]
gpa = [4.00, 2.50, 4.00, 3.90, 3.75, 3.80, 2.90, 3.10, 3.25, 3.40, 3.30, 3.90, 1.35, 4.00, 1.00, 3.85, 2.98, 2.75, 2.75, 3.60, 3.50, 3.50, 3.50, 3.85, 2.95, 3.95, 3.65, 3.55, 3.58, 2.98, 1.50, 1.75, 2.20, 3.00, 3.00, 3.00, 3.15, 3.90, 3.15, 3.85, 2.70, 1.00, 3.25, 3.90, 2.80, 3.50, 3.40, 2.30, 2.50, 2.35]

table = pd.DataFrame(days, columns = ['Days Present']); table['GPA'] = gpa
table
table.style.set_properties(**{'text-align' : 'center'})
# Out:
#         <style  type="text/css" >
#
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row0_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row0_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row1_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row1_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row2_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row2_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row3_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row3_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row4_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row4_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row5_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row5_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row6_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row6_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row7_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row7_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row8_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row8_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row9_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row9_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row10_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row10_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row11_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row11_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row12_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row12_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row13_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row13_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row14_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row14_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row15_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row15_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row16_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row16_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row17_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row17_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row18_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row18_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row19_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row19_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row20_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row20_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row21_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row21_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row22_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row22_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row23_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row23_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row24_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row24_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row25_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row25_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62e9eacf_81bd_11e9_8b7c_782bcb97f042row26_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_62

# %%
x = [180, 150, 170, 180, 177, 180, 140, 169, 168, 152, 150, 170, 109, 180, 108, 175, 144, 120, 133, 160, 160, 159, 165, 180, 149, 180, 160, 155, 156, 145, 122, 131, 156, 166, 170, 155, 158, 170, 160, 165, 159, 119, 168, 175, 161, 160, 160, 150, 140, 148]
y = [4.00, 2.50, 4.00, 3.90, 3.75, 3.80, 2.90, 3.10, 3.25, 3.40, 3.30, 3.90, 1.35, 4.00, 1.00, 3.85, 2.98, 2.75, 2.75, 3.60, 3.50, 3.50, 3.50, 3.85, 2.95, 3.95, 3.65, 3.55, 3.58, 2.98, 1.50, 1.75, 2.20, 3.00, 3.00, 3.00, 3.15, 3.90, 3.15, 3.85, 2.70, 1.00, 3.25, 3.90, 2.80, 3.50, 3.40, 2.30, 2.50, 2.35]

import matplotlib.pyplot as plt

plt.scatter(x, y, c = "darkorange", s = 100, marker = "o")
plt.xlabel("Days Present", fontsize = 12); plt.ylabel("GPA", fontsize = 12)
plt.xticks(size = 10); plt.yticks(size = 10)
plt.title("Days Present versus GPA", fontsize = 15)
plt.show();

# %% [markdown]
# **Conclusion:** The graph shown, as the number of days present in class increase, the GPA also increases.
#
# **Type of Relation:** Positive Linear Correlation

# %% [markdown]
# ### <font color = "orange">Question 7</font>
#
# By referring to table in Question 5, calculate the **correlation coefficient, r** step by step.

# %%
x = [180, 150, 170, 180, 177, 180, 140, 169, 168, 152, 150, 170, 109, 180, 108, 175, 144, 120, 133, 160, 160, 159, 165, 180, 149, 180, 160, 155, 156, 145, 122, 131, 156, 166, 170, 155, 158, 170, 160, 165, 159, 119, 168, 175, 161, 160, 160, 150, 140, 148]
y = [4.00, 2.50, 4.00, 3.90, 3.75, 3.80, 2.90, 3.10, 3.25, 3.40, 3.30, 3.90, 1.35, 4.00, 1.00, 3.85, 2.98, 2.75, 2.75, 3.60, 3.50, 3.50, 3.50, 3.85, 2.95, 3.95, 3.65, 3.55, 3.58, 2.98, 1.50, 1.75, 2.20, 3.00, 3.00, 3.00, 3.15, 3.90, 3.15, 3.85, 2.70, 1.00, 3.25, 3.90, 2.80, 3.50, 3.40, 2.30, 2.50, 2.35]

#Step 1: Find the mean of height and mean of weight
meanX = sum(x) / len(x)
meanY = sum(y) / len(y)

print "1. Mean of Height (cm) is ", meanX
print "2. Mean of Weight (kg) is ", meanY

#Step 2: Subtract the mean of x from every x value (assign as a) and mean of y from every y value (assign as b)
a = []
for i in x:
    a.append(i - meanX)

b = []
for j in y:
    b.append(j - meanY)

#Step 3: Calculate (a x b), summation of a-squared and summation of b-squared
ab = []
for k in range(len(a)):
    ab.append(a[k] * b[k])

aSquared = []
for l in x:
    aSquared.append((l - meanX) ** 2)

bSquared = []
for m in y:
    bSquared.append((m - meanY) ** 2)

#Step 4: Sum up ab, sum up aSquared and bSquared

print "3. Summation of (a x b) is ", sum(ab)
print "4. Summation of a-squared is ", sum(aSquared)
print "5. Summation od b-squared is ", sum(bSquared)

#Step 5: Find the correlation coefficient, r
AB = ((sum(aSquared)) * (sum(bSquared)))
sqrtAB = AB ** (0.5)

r = sum(ab) / sqrtAB
print "6. The correlation coefficient, r is ", r
# Out:
# 1. Mean of Height (cm) is  156
# 2. Mean of Weight (kg) is  3.1058
# 3. Summation of (a x b) is  612.3614
# 4. Summation of a-squared is  16769
# 5. Summation od b-squared is  29.820018
# 6. The correlation coefficient, r is  0.865964870267

# %% [markdown]
# ### <font color = "orange">Question 8</font>
#
# By referring to table in Question 5, import **numpy** and use it to calculate **the correlation coefficient, r** and compare with your previous **r**.

# %%
import numpy as np

print "The correlation coefficient is "
print np.corrcoef(x, y)
# Out:
# The correlation coefficient is
# [[ 1.          0.86611415]
#  [ 0.86611415  1.        ]]

# %% [markdown]
# ### <font color = "darkorchid">Question 9</font>
#
# A study was conducted to investigate the relationship between Height and Shoe Size. Create the lists for Height (as x) and Shoe Size (as y).

# %%
height = [173.0, 173.0, 162.0, 163.0, 172.0, 170.0, 171.0, 167.0, 162.0, 151.0, 149.9, 149.9, 170.0, 175.0, 167.0]
shoesize = [6.0, 9.0, 7.0, 8.0, 11.0, 10.0, 8.0, 7.0, 7.0, 6.0, 4.0, 4.0, 10.0, 10.5, 6]

table = pd.DataFrame(height, columns = ['Height (cm)']); table['Shoe Size'] = shoesize
table
table.style.set_properties(**{'text-align' : 'center'})
# Out:
#         <style  type="text/css" >
#
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row0_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row0_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row1_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row1_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row2_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row2_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row3_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row3_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row4_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row4_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row5_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row5_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row6_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row6_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row7_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row7_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row8_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row8_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row9_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row9_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row10_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row10_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row11_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row11_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row12_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row12_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row13_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row13_col1 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row14_col0 {
#
#                 text-align:  center;
#
#             }
#
#             #T_ed6e4661_81bd_11e9_9813_782bcb97f042row14_col1 {
#
#                 text-align:  center;
#
#             }
#
#         </style>
#
#         <table id="T_ed6e4661_81bd_11e9_9813_782bcb97f042" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">Height (cm)
#
#                 <th class="col_heading level0 col1">Shoe Size
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_ed6e4661_81bd_11e9_9813_782bcb97f042" class="row_heading level1 row0">
#                     0
#
#                 <td id="T_ed6e4661_81bd_11e9_9813_782bcb97f042row0_col0" class="data row0 col0">
#                     173
#
#                 <td id="T_ed6e4661_81bd_11e9_9813_782bcb97f042row0_col1" class="data row0 col1">
#                     6
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_ed6e4661_81bd_11e9_9813_782bcb97f042" class="row_heading level1 row1">
#                     1
#
#                 <td id="T_ed6e4661_81bd_11e9_9813_782bcb97f042row1_col0" class="data row1 col0">
#                     173
#
#                 <td id="T_ed6e4661_81bd_11e9_9813_782bcb97f042row1_col1" class="data row1 col1">
#                     9
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_ed6e4661_81bd_11e9_9813_782bcb97f042" class="row_heading level1 row2">
#                     2
#
#                 <td id="T_ed6e4661_81bd_11e9_9813_782bcb97f042row2_col0" class="data row2 col0">
#                     162
#
#                 <td id="T_ed6e4661_81bd_11e9_9813_782bcb97f042row2_col1" class="data row2 col1">
#                     7
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_ed6e4661_81bd_11e9_9813_782bcb97f042" class="row_heading level1 row3">
#                     3
#
#                 <td id="T_ed6e4661_81bd_11e9_9813_782bcb97f042row3_col0" class="data row3 col0">
#                     163
#
#                 <td id="T_ed6e4661_81bd_11e9_9813_782bcb97f042row3_col1" class="data row3 col1">
#                     8
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_ed6e4661_81bd_11e9_9813_782bcb97f042" class="row_heading level1 row4">
#                     4
#
#                 <td id="T_ed6e4661_81bd_11e9_9813_782bcb97f042row4_col0" class="data row4 col0">
#                     172
#
#                 <td id="T_ed6e4661_81bd_11e9_9813_782bcb97f042row4_col1" class="data row4 col1">
#                     11
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_ed6e4661_81bd_11e9_9813_782bcb97f042" class="row_heading level1 row5">
#                     5
#
#                 <td id="T_ed6e4661_81bd_11e9_9813_782bcb97f042row5_col0" class="data row5 col0">
#                     170
#
#                 <td id="T_ed6e4661_81bd_11e9_9813_782bcb97f042row5_col1" class="data row5 col1">
#                     10
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_ed6e4661_81bd_11e9_9813_782bcb97f042" class="row_heading level1 row6">
#                     6

# %%
height = [173.0, 173.0, 162.0, 163.0, 172.0, 170.0, 171.0, 167.0, 162.0, 151.0, 149.9, 149.9, 170.0, 175.0, 167.0]
shoesize = [6.0, 9.0, 7.0, 8.0, 11.0, 10.0, 8.0, 7.0, 7.0, 6.0, 4.0, 4.0, 10.0, 10.5, 6]

import matplotlib.pyplot as plt

plt.scatter(height, shoesize, c = "darkorchid", s = 100, marker = "o")
plt.xlabel("Height (cm)", fontsize = 12); plt.ylabel("Shoe Size", fontsize = 12)
plt.xticks(size = 10); plt.yticks(size = 10)
plt.title("Height (cm) versus Shoe Size", fontsize = 15)
plt.show();

# %% [markdown]
# ### <font color = "darkorchid">Question 10</font>
#
# By referring to table in Question 9, import **numpy** and use it to calculate **the correlation coefficient, r** and write down a short conclusion with your r value.

# %%
import numpy as np

print np.corrcoef(height, shoesize)
# Out:
# [[ 1.         0.7746235]
#  [ 0.7746235  1.       ]]

# %% [markdown]
# **Conclusion:** The correlation coefficient, r = 0.78 shown that the relation between height and shoe size is low positive correlation as well as the graph plotted.
