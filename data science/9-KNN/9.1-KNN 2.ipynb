# %%
import pandas as pd
url='https://raw.githubusercontent.com/coding-blocks-archives/machine-learning-online-2018/master/13.%20Decision%20Trees/titanic.csv'
data = pd.read_csv(url)
clean=['Name','PassengerId','Parch','Cabin','Embarked','Ticket']
data_clean=data.drop(clean,axis=1)
data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 6 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Fare        891 non-null float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 41.8+ KB

# %%
dic={'male':0,'female':1}
data_clean.Sex=data_clean.Sex.map(dic)
data_clean.Sex
#data_clean=data_clean.fillna(data_clean.Age.mean())
data_clean.describe()


X=data_clean[['Sex','Fare']]
y=data_clean['Survived']

# %%
X
# Out:
#      Sex      Fare
# 0      0    7.2500
# 1      1   71.2833
# 2      1    7.9250
# 3      1   53.1000
# 4      0    8.0500
# 5      0    8.4583
# 6      0   51.8625
# 7      0   21.0750
# 8      1   11.1333
# 9      1   30.0708
# 10     1   16.7000
# 11     1   26.5500
# 12     0    8.0500
# 13     0   31.2750
# 14     1    7.8542
# 15     1   16.0000
# 16     0   29.1250
# 17     0   13.0000
# 18     1   18.0000
# 19     1    7.2250
# 20     0   26.0000
# 21     0   13.0000
# 22     1    8.0292
# 23     0   35.5000
# 24     1   21.0750
# 25     1   31.3875
# 26     0    7.2250
# 27     0  263.0000
# 28     1    7.8792
# 29     0    7.8958
# ..   ...       ...
# 861    0   11.5000
# 862    1   25.9292
# 863    1   69.5500
# 864    0   13.0000
# 865    1   13.0000
# 866    1   13.8583
# 867    0   50.4958
# 868    0    9.5000
# 869    0   11.1333
# 870    0    7.8958
# 871    1   52.5542
# 872    0    5.0000
# 873    0    9.0000
# 874    1   24.0000
# 875    1    7.2250
# ...

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     0
# 13     0
# 14     0
# 15     1
# 16     0
# 17     1
# 18     0
# 19     1
# 20     0
# 21     1
# 22     1
# 23     1
# 24     0
# 25     1
# 26     0
# 27     0
# 28     1
# 29     0
#       ..
# 861    0
# 862    1
# 863    0
# 864    0
# 865    1
# 866    1
# 867    0
# 868    0
# 869    1
# 870    0
# 871    1
# 872    0
# 873    0
# 874    1
# 875    1
# 876    0
# 877    0
# 878    0
# 879    1
# 880    1
# 881    0
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=3)
model.fit(X,y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#            weights='uniform')

# %%
model.score(X,y)
# Out:
# 0.8619528619528619

# %%
model.predict([[1,7]])
# Out:
# array([1])

# %%
from matplotlib import pyplot as plt
score=[KNeighborsClassifier(n_neighbors=i).fit(X,y).score(X,y) for i in range(3,16)]

plt.plot(range(3,16),score)
plt.show()

# %%
score
# Out:
# [0.8619528619528619,
#  0.8338945005611672,
#  0.8271604938271605,
#  0.8148148148148148,
#  0.8114478114478114,
#  0.8002244668911336,
#  0.8080808080808081,
#  0.797979797979798,
#  0.7946127946127947,
#  0.7957351290684624,
#  0.7833894500561167,
#  0.792368125701459,
#  0.792368125701459]
