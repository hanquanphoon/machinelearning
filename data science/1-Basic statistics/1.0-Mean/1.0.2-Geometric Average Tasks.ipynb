# %% [markdown]
# # <font color="crimson">Geometric Average Tasks</font>

# %% [markdown]
# ## <font color="mediumaquamarine">PART 1:</font>
#
# <font size="4" >The table below shows the Return On Investment (ROI) in dollars, $ for company XYZ in 5 years. Using geometric average, calculate the average ROI of the company througout the years.</font>
#
# <img src="geoMean.PNG">
#
# ### Task 1:
# <font size="4" >Store the value of ROI into a list as x. Then, find the value of sample size, n.</font>

# %% [markdown]
# ### Task 2:
# <font size=4>Find the product of all x values.</font>
#
# ### <font color="red">Hint:</font>
# <font size=4>Intialize the product of x to 1 first. Then, use for loop to calculate the product of all x values.</font>

# %% [markdown]
# ### Task 3:
# <font size=4>Root the product of x to the nth root. Note that it depends on the n value.</font>
#
# ### <font color="red">Hint:</font>
# <font size=4>Use the formula **power of (1/n)**.</font>

# %% [markdown]
# ### Task 4:
# <font size=4>Now, find the geometric average using python libraries.</font>
#
# ### <font color="red">Hint:</font>
# <font size=4>- Import gmean from scipy.stats.mstats<br>- Use **gmean(data)** function</font>

# %% [markdown]
# ## <font color="mediumaquamarine">PART 2:</font>
#
# <font size="4" >The table below shows the population density of a bacteria against time, measured using spectrophometer. This indicates the growth of the bacteria. Using geometric average, calculate the average density population throughout the 80 minutes.</font>
#
# <img src="geoMean2.PNG">
#
# ### Task 1:
# <font size="4" >Store the value of population density into a list as x. Then, find the value of sample size, n.</font>

# %% [markdown]
# ### Task 2:
# <font size=4>Find the product of all x values.</font>
#
# ### <font color="red">Hint:</font>
# <font size=4>Intialize the product of x to 1 first. Then, use for loop to calculate the product of all x values.</font>

# %% [markdown]
# ### Task 3:
# <font size=4>Root the product of x to the nth root. Note that it depends on the n value.</font>
#
# ### <font color="red">Hint:</font>
# <font size=4>Use the formula **power of (1/n)**.</font>

# %% [markdown]
# ### Task 4:
# <font size=4>Now, find the geometric average using python libraries.</font>
#
# ### <font color="red">Hint:</font>
# <font size=4>- Import gmean from scipy.stats.mstats<br>- Use **gmean(data)** function</font>

# %% [markdown]
# ## <font color="mediumaquamarine">PART 3:</font>
#
# <font size="4" >The table below shows the annual salary of a worker in 5 years, which increases for 5% in each year. Using geometric average, calculate his average annual salary in the 5 years.</font>
#
# <img src="geoMean3.PNG">
#
# ### Task 1:
# <font size="4" >Store the value of annual salary into a list as x. Then, find the value of sample size, n.</font>

# %% [markdown]
# ### Task 2:
# <font size=4>Find the product of all x values.</font>
#
# ### <font color="red">Hint:</font>
# <font size=4>Intialize the product of x to 1 first. Then, use for loop to calculate the product of all x values.</font>

# %% [markdown]
# ### Task 3:
# <font size=4>Root the product of x to the nth root. Note that it depends on the n value.</font>
#
# ### <font color="red">Hint:</font>
# <font size=4>Use the formula **power of (1/n)**.</font>

# %% [markdown]
# ### Task 4:
# <font size=4>Now, find the geometric average using python libraries.</font>
#
# ### <font color="red">Hint:</font>
# <font size=4>- Import gmean from scipy.stats.mstats<br>- Use **gmean(data)** function</font>
